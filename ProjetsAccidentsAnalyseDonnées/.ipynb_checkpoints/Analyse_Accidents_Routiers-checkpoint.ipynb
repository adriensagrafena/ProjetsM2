# %% [markdown]
# # Analyse de données sur les accidents routiers corporels en 2019
# `Valentine CROIBIEN - Adrien SAGRAFENA`

# %% [markdown]
# # Création du jeu de données
# ## Importation des bibliothèques nécessaires

# %%
import pandas as pd
import numpy as np
from datetime import date as dt
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importation des données et choix des variables

# %% [markdown]
# ### Données correspondant aux caractéristiques de l'accident

# %%
carac = pd.read_csv("caracteristiques-2019.csv", sep=";")
var_carac = ["Num_Acc","jour","mois","hrmn","lum","dep","com","agg","int","atm","col"]
carac = carac[var_carac]
carac.describe(include = "all")
# Out:
#              Num_Acc          jour          mois   hrmn           lum    dep  \
# count   5.884000e+04  58840.000000  58840.000000  58840  58840.000000  58840
# unique           NaN           NaN           NaN   1386           NaN    107
# top              NaN           NaN           NaN  18:00           NaN     75
# freq             NaN           NaN           NaN    784           NaN   5610
# mean    2.019000e+11     15.683396      6.687542    NaN      1.944867    NaN
# std     1.698579e+04      8.719610      3.387344    NaN      1.504409    NaN
# min     2.019000e+11      1.000000      1.000000    NaN      1.000000    NaN
# 25%     2.019000e+11      8.000000      4.000000    NaN      1.000000    NaN
# 50%     2.019000e+11     16.000000      7.000000    NaN      1.000000    NaN
# 75%     2.019000e+11     23.000000     10.000000    NaN      3.000000    NaN
# max     2.019001e+11     31.000000     12.000000    NaN      5.000000    NaN
#
#           com           agg           int           atm           col
# count   58840  58840.000000  58840.000000  58840.000000  58840.000000
# unique  11444           NaN           NaN           NaN           NaN
# top     75116           NaN           NaN           NaN           NaN
# freq      629           NaN           NaN           NaN           NaN
# mean      NaN      1.645887      2.025357      1.617794      4.165058
# std       NaN      0.478248      1.997756      1.677988      1.954030
# min       NaN      1.000000      1.000000     -1.000000     -1.000000
# 25%       NaN      1.000000      1.000000      1.000000      3.000000
# 50%       NaN      2.000000      1.000000      1.000000      3.000000
# 75%       NaN      2.000000      2.000000      1.000000      6.000000
# max       NaN      2.000000      9.000000      9.000000      7.000000

# %% [markdown]
# ### Données correspondant aux usagers impliqués dans l'accident

# %%
usagers = pd.read_csv("usagers-2019.csv", sep=";")
var_usagers = ["Num_Acc","id_vehicule","catu","place", "grav","sexe","an_nais","trajet"]
usagers = usagers[var_usagers]
usagers.describe(include = "all")
# Out:
#              Num_Acc  id_vehicule           catu          place  \
# count   1.329770e+05       132977  132977.000000  132977.000000
# unique           NaN        98670            NaN            NaN
# top              NaN  138 212 691            NaN            NaN
# freq             NaN           33            NaN            NaN
# mean    2.019000e+11          NaN       1.352587       2.184754
# std     1.699444e+04          NaN       0.630635       2.695724
# min     2.019000e+11          NaN       1.000000       1.000000
# 25%     2.019000e+11          NaN       1.000000       1.000000
# 50%     2.019000e+11          NaN       1.000000       1.000000
# 75%     2.019000e+11          NaN       2.000000       2.000000
# max     2.019001e+11          NaN       3.000000      10.000000
#
#                  grav           sexe        an_nais         trajet
# count   132977.000000  132977.000000  132977.000000  132977.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         2.542635       1.320304    1980.079600       3.224279
# std          1.371815       0.466595      19.164625       2.667380
# min          1.000000       1.000000    1900.000000      -1.000000
# 25%          1.000000       1.000000    1967.000000       0.000000
# 50%          3.000000       1.000000    1983.000000       4.000000
# 75%          4.000000       2.000000    1995.000000       5.000000
# max          4.000000       2.000000    2019.000000       9.000000

# %% [markdown]
# ## Jointure des deux jeux de données

# %%
victime = usagers.merge(carac, on="Num_Acc")

# %% [markdown]
# ## Création de la variable `Date` à partir des variables `jour` et `mois`

# %%
date = []
for i in range(len(victime)):
    jour = victime["jour"][i]
    mois = victime["mois"][i]
    jour_mois = str(mois) + "/" + str(jour) + "/2019"
    date.append(jour_mois)
    
victime["date"] = date

victime["date"] = pd.to_datetime(victime['date'])

victime = victime.drop(columns = ["jour", "mois"])
victime.describe(include = "all")
# Out:
# C:\Users\Adrien\AppData\Local\Temp/ipykernel_13948/4097898379.py:13: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   victime.describe(include = "all")
#              Num_Acc  id_vehicule           catu          place  \
# count   1.329770e+05       132977  132977.000000  132977.000000
# unique           NaN        98670            NaN            NaN
# top              NaN  138 212 691            NaN            NaN
# freq             NaN           33            NaN            NaN
# first            NaN          NaN            NaN            NaN
# last             NaN          NaN            NaN            NaN
# mean    2.019000e+11          NaN       1.352587       2.184754
# std     1.699444e+04          NaN       0.630635       2.695724
# min     2.019000e+11          NaN       1.000000       1.000000
# 25%     2.019000e+11          NaN       1.000000       1.000000
# 50%     2.019000e+11          NaN       1.000000       1.000000
# 75%     2.019000e+11          NaN       2.000000       2.000000
# max     2.019001e+11          NaN       3.000000      10.000000
#
#                  grav           sexe        an_nais         trajet    hrmn  \
# count   132977.000000  132977.000000  132977.000000  132977.000000  132977
# unique            NaN            NaN            NaN            NaN    1386
# top               NaN            NaN            NaN            NaN   18:00
# freq              NaN            NaN            NaN            NaN    1870
# first             NaN            NaN            NaN            NaN     NaN
# last              NaN            NaN            NaN            NaN     NaN
# mean         2.542635       1.320304    1980.079600       3.224279     NaN
# std          1.371815       0.466595      19.164625       2.667380     NaN
# min          1.000000       1.000000    1900.000000      -1.000000     NaN
# 25%          1.000000       1.000000    1967.000000       0.000000     NaN
# 50%          3.000000       1.000000    1983.000000       4.000000     NaN
# 75%          4.000000       2.000000    1995.000000       5.000000     NaN
# max          4.000000       2.000000    2019.000000       9.000000     NaN
#
#                   lum     dep     com            agg            int  \
# count   132977.000000  132977  132977  132977.000000  132977.000000
# unique            NaN     107   11444            NaN            NaN
# top               NaN      75   75116            NaN            NaN
# freq              NaN   11895    1418            NaN            NaN
# first             NaN     NaN     NaN            NaN            NaN
# last              NaN     NaN     NaN            NaN            NaN
# mean         1.932710     NaN     NaN       1.622596       2.016552
# std          1.495194     NaN     NaN       0.484739       1.982705
# min          1.000000     NaN     NaN       1.000000       1.000000
# 25%          1.000000     NaN     NaN       1.000000       1.000000
# 50%          1.000000     NaN     NaN       2.000000       1.000000
# 75%          3.000000     NaN     NaN       2.000000       2.000000
# max          5.000000     NaN     NaN       2.000000       9.000000
#
#                   atm            col                 date
# count   132977.000000  132977.000000               132977
# unique            NaN            NaN                  365
# top               NaN            NaN  2019-06-21 00:00:00
# freq              NaN            NaN                  571
# first             NaN            NaN  2019-01-01 00:00:00
# last              NaN            NaN  2019-12-31 00:00:00
# mean         1.614279       3.890071                  NaN
# std          1.672985       1.862988                  NaN
# min         -1.000000      -1.000000                  NaN
# 25%          1.000000       3.000000                  NaN
# 50%          1.000000       3.000000                  NaN
# 75%          1.000000       6.000000                  NaN
# max          9.000000       7.000000                  NaN

# %% [markdown]
# ## Changement du type des variables

# %% [markdown]
# ### La variable `Num_Acc` devient une variable caractère

# %%
num = []
for i in range(len(victime)):
    num.append(str(victime["Num_Acc"][i]))
    
victime["Num_Acc"] = num

# %% [markdown]
# ### Les variables `lum`, `agg`, `int`, `col`, `atm`, `catu`, `grav`, `sexe`, `trajet`, `place` deviennent des variables catégorielles.

# %% [markdown]
# ### Changement modalités des variables

# %%
lum = ["Plein jour", "Crépuscule ou aube","Nuit sans éclairage public","Nuit avec éclairage public non allumé",
       "Nuit avec éclairage public allumé"]
v_lum = []

for i in range(len(victime)):
    j = victime["lum"][i] - 1
    v_lum.append(lum[j])
    
victime["lum"] = v_lum

# %%
agg = ["Hors agglomération", "En agglomération"]
v_agg = []

for i in range(len(victime)):
    j = victime["agg"][i] - 1
    v_agg.append(agg[j])
    
victime["agg"] = v_agg

# %%
inte = ["Hors intersection","Intersection en X","Intersection en T","Intersection en Y","Intersection à plus de 4 branches",  
        "Giratoire","Place","Passage à niveau","Autre intersection"]

v_int = []

for i in range(len(victime)):
    j = victime["int"][i] - 1
    v_int.append(inte[j])
    
victime["int"] = v_int

# %% [markdown]
# ### Suppression des accidents dont le type de condition atmosphérique n'a pas été indiqué

# %%
victime.loc[(victime['atm'] == -1 ),:].shape[0]
# Out:
# 1

# %%
victime = victime.loc[~(victime['atm'] == -1 ),:]

# %%
victime.groupby("atm").size()
# Out:
# atm
# 1    105340
# 2     14749
# 3      3244
# 4       617
# 5       723
# 6       367
# 7      2336
# 8      4944
# 9       656
# dtype: int64

# %%
atm = ["Normale", "Pluie légère", "Pluie forte", "Neige - Grêle", "Brouillard - Fumée", "Vent fort - Tempête", 
       "Temps éblouissant", "Temps couvert", "Autre"]

v_atm = []

for i in victime.index.values:
    j = victime["atm"][i] - 1
    v_atm.append(atm[j])
    
victime["atm"] = v_atm

# %% [markdown]
# ### Suppression des accidents dont le type de collision n'a pas été indiqué

# %%
victime.loc[(victime['col'] == -1 ),:].shape[0]
# Out:
# 1

# %%
victime = victime.loc[~(victime['col'] == -1 ),:]

# %%
victime.groupby("col").size()
# Out:
# col
# 1    13956
# 2    17977
# 3    40350
# 4     9292
# 5     7899
# 6    34838
# 7     8663
# dtype: int64

# %%
col = ["Deux véhicules - frontale", "Deux véhicules - par l'arrière", "Deux véhicules - par le côté", 
       "Trois véhicules et plus - en chaîne", "Trois véhicules et plus - collisions multiples", "Autre collision", 
       "Sans collision"]

v_col = []
for i in victime.index.values:
    j = victime["col"][i] - 1
    v_col.append(col[j])
    
victime["col"] = v_col

# %%
grav = ["Indemne", "Tué", "Blessé hospitalisé", "Blessé léger"]

v_grav = []
for i in victime.index.values:
    j = victime["grav"][i] - 1
    v_grav.append(grav[j])
    
victime["grav"] = v_grav

# %%
sexe = ["Masculin", "Féminin"]
v_sexe = []
for i in victime.index.values:
    j = victime["sexe"][i] - 1
    v_sexe.append(sexe[j])
    
victime["sexe"] = v_sexe

# %%
trajet = ["Autre", "Domicile – travail", "Domicile – école", "Courses – achats", 
          "Utilisation professionnelle", "Promenade – loisirs"]

v_traj = []
for i in victime.index.values:
    if (victime["trajet"][i] == -1) or (victime["trajet"][i] == 9):
        v_traj.append(trajet[0])
    else :
        j = victime["trajet"][i]
        v_traj.append(trajet[j])
victime["trajet"] = v_traj

# %%
place = ["Conducteur", "Passager Avant", "Passager", "Passager", "Passager", "Passager Avant", "Passager", 
         "Passager", "Passager", "Piéton"]
v_place = []
for i in victime.index.values:
    j = victime["place"][i] - 1
    v_place.append(place[j])

        
victime["place"] = v_place

# %%
victime["lum"] = victime["lum"].astype("category")
victime["agg"] = victime["agg"].astype("category")
victime["int"] = victime["int"].astype("category")
victime["col"] = victime["col"].astype("category")
victime["atm"] = victime["atm"].astype("category")
victime["catu"] = victime["catu"].astype("category")
victime["grav"] = victime["grav"].astype("category")
victime["sexe"] = victime["sexe"].astype("category")
victime["trajet"] = victime["trajet"].astype("category")
victime["place"] = victime["place"].astype("category")

# %% [markdown]
# ## Création d'une variable correspondant au nombre de véhicules impliqués dans l'accident

# %%
eff_veh = victime.groupby("Num_Acc")["id_vehicule"].nunique()

eff_veh = eff_veh.reset_index()
eff_veh.columns = ["Num_Acc", "nb_veh"]

victime = pd.merge(victime,eff_veh, on = "Num_Acc")

# %%
eff_ind = victime.groupby("Num_Acc").size()

eff_ind = eff_ind.reset_index()
eff_ind.columns = ["Num_Acc", "nb_ind"]

victime = pd.merge(victime,eff_ind, on = "Num_Acc")

# %% [markdown]
# ## Création d'une variable `age` à partir de l'année de naissance

# %%
victime["age"] = 2019 - victime["an_nais"]

# %% [markdown]
# ### Suppression de la variable `an_nais`

# %%
victime = victime.drop(columns=["an_nais"])

# %% [markdown]
# ## Résumé des données

# %% [markdown]
# ### Les variables disponibles et leur type

# %%
victime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 132975 entries, 0 to 132974
# Data columns (total 19 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Num_Acc      132975 non-null  object
#  1   id_vehicule  132975 non-null  object
#  2   catu         132975 non-null  category
#  3   place        132975 non-null  category
#  4   grav         132975 non-null  category
#  5   sexe         132975 non-null  category
#  6   trajet       132975 non-null  category
#  7   hrmn         132975 non-null  object
#  8   lum          132975 non-null  category
#  9   dep          132975 non-null  object
#  10  com          132975 non-null  object
#  11  agg          132975 non-null  category
#  12  int          132975 non-null  category
#  13  atm          132975 non-null  category
#  14  col          132975 non-null  category
#  15  date         132975 non-null  datetime64[ns]
#  16  nb_veh       132975 non-null  int64
#  17  nb_ind       132975 non-null  int64
#  18  age          132975 non-null  int64
# dtypes: category(10), datetime64[ns](1), int64(3), object(5)
# memory usage: 11.4+ MB

# %% [markdown]
# ### Sommaire des variables

# %%
victime.describe(include="all")
# Out:
# C:\Users\Adrien\AppData\Local\Temp/ipykernel_13948/1137599290.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   victime.describe(include="all")
#              Num_Acc  id_vehicule      catu       place     grav      sexe  \
# count         132975       132975  132975.0      132975   132975    132975
# unique         58838        98668       3.0           4        4         2
# top     201900049689  138 212 691       1.0  Conducteur  Indemne  Masculin
# freq              33           33   97355.0       96934    55314     90382
# first            NaN          NaN       NaN         NaN      NaN       NaN
# last             NaN          NaN       NaN         NaN      NaN       NaN
# mean             NaN          NaN       NaN         NaN      NaN       NaN
# std              NaN          NaN       NaN         NaN      NaN       NaN
# min              NaN          NaN       NaN         NaN      NaN       NaN
# 25%              NaN          NaN       NaN         NaN      NaN       NaN
# 50%              NaN          NaN       NaN         NaN      NaN       NaN
# 75%              NaN          NaN       NaN         NaN      NaN       NaN
# max              NaN          NaN       NaN         NaN      NaN       NaN
#
#                      trajet    hrmn         lum     dep     com  \
# count                132975  132975      132975  132975  132975
# unique                    6    1386           5     107   11443
# top     Promenade – loisirs   18:00  Plein jour      75   75116
# freq                  52020    1870       88619   11895    1418
# first                   NaN     NaN         NaN     NaN     NaN
# last                    NaN     NaN         NaN     NaN     NaN
# mean                    NaN     NaN         NaN     NaN     NaN
# std                     NaN     NaN         NaN     NaN     NaN
# min                     NaN     NaN         NaN     NaN     NaN
# 25%                     NaN     NaN         NaN     NaN     NaN
# 50%                     NaN     NaN         NaN     NaN     NaN
# 75%                     NaN     NaN         NaN     NaN     NaN
# max                     NaN     NaN         NaN     NaN     NaN
#
#                      agg                int      atm  \
# count             132975             132975   132975
# unique                 2                  9        9
# top     En agglomération  Hors intersection  Normale
# freq               82789              87067   105339
# first                NaN                NaN      NaN
# last                 NaN                NaN      NaN
# mean                 NaN                NaN      NaN
# std                  NaN                NaN      NaN
# min                  NaN                NaN      NaN
# 25%                  NaN                NaN      NaN
# 50%                  NaN                NaN      NaN
# 75%                  NaN                NaN      NaN
# max                  NaN                NaN      NaN
#
#                                  col                 date         nb_veh  \
# count                         132975               132975  132975.000000
# unique                             7                  365            NaN
# top     Deux véhicules - par le côté  2019-06-21 00:00:00            NaN
# freq                           40350                  571            NaN
# first                            NaN  2019-01-01 00:00:00            NaN
# last                             NaN  2019-12-31 00:00:00            NaN
# mean                             NaN                  NaN       1.882737
# std                              NaN                  NaN       0.830809
# min                              NaN                  NaN       1.000000
# 25%                              NaN                  NaN       1.000000
# 50%                              NaN                  NaN       2.000000
# 75%                              NaN                  NaN       2.000000
# max                              NaN                  NaN      12.000000
#
#                nb_ind            age
# count   132975.000000  132975.000000
# unique            NaN            NaN
# top               NaN            NaN
# freq              NaN            NaN
# first             NaN            NaN
# last              NaN            NaN
# mean         2.916646      38.920090
# std          2.030270      19.164135
# min          1.000000       0.000000
# 25%          2.000000      24.000000
# 50%          2.000000      36.000000
# 75%          3.000000      52.000000
# max         33.000000     119.000000

# %% [markdown]
# ## Valeurs manquantes et aberrantes

# %% [markdown]
# ### Valeurs manquantes

# %%
victime.isna().sum()
# Out:
# Num_Acc        0
# id_vehicule    0
# catu           0
# place          0
# grav           0
# sexe           0
# trajet         0
# hrmn           0
# lum            0
# dep            0
# com            0
# agg            0
# int            0
# atm            0
# col            0
# date           0
# nb_veh         0
# nb_ind         0
# age            0
# dtype: int64

# %% [markdown]
# Il n'y a donc aucune valeur manquante.
#
# ### Valeur aberrantes

# %%
victime.groupby(["age",'catu']).size()
# Out:
# age  catu
# 0    1         2
#      2       194
#      3        14
# 1    1         0
#      2       296
#             ...
# 118  2        12
#      3         3
# 119  1       115
#      2        12
#      3         6
# Length: 312, dtype: int64

# %% [markdown]
# Nous remarquons énormément d'individus de plus de 100 (avec un âge allant jusque 119 ans). Nous les supprimons donc.
# De plus, nous supprimons également les individus indiqués comme conducteurs `catu = 1` étant agés de moins de 16 ans.

# %% [markdown]
# #### Nombre de personnes de plus de 100 ans

# %%
victime.loc[victime["age"]>100,:].shape[0]
# Out:
# 177

# %% [markdown]
# #### Nombre de conducteurs de moins de 16 ans

# %%
victime.loc[(victime["catu"]== 1) & (victime["age"] < 16),:].shape[0]
# Out:
# 1071

# %% [markdown]
# #### Suppression des usagers de plus de 100 ans et des conducteurs de moins de 16 ans

# %%
victime = victime.loc[~((victime["catu"]== 1) & (victime["age"] < 16) | (victime["age"] > 100)),:]

# %%
victime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131727 entries, 0 to 132974
# Data columns (total 19 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Num_Acc      131727 non-null  object
#  1   id_vehicule  131727 non-null  object
#  2   catu         131727 non-null  category
#  3   place        131727 non-null  category
#  4   grav         131727 non-null  category
#  5   sexe         131727 non-null  category
#  6   trajet       131727 non-null  category
#  7   hrmn         131727 non-null  object
#  8   lum          131727 non-null  category
#  9   dep          131727 non-null  object
#  10  com          131727 non-null  object
#  11  agg          131727 non-null  category
#  12  int          131727 non-null  category
#  13  atm          131727 non-null  category
#  14  col          131727 non-null  category
#  15  date         131727 non-null  datetime64[ns]
#  16  nb_veh       131727 non-null  int64
#  17  nb_ind       131727 non-null  int64
#  18  age          131727 non-null  int64
# dtypes: category(10), datetime64[ns](1), int64(3), object(5)
# memory usage: 11.3+ MB

# %%
victime.groupby(["age",'catu']).size()
# Out:
# age  catu
# 0    1         0
#      2       194
#      3        14
# 1    1         0
#      2       296
#             ...
# 99   2         0
#      3         4
# 100  1         1
#      2         2
#      3         0
# Length: 303, dtype: int64

# %% [markdown]
# ## Calendrier avec gradient de couleurs pour la représentation du nombre d'accidents par jour

# %%
calend = victime.groupby("date")["Num_Acc"].agg('nunique')

calend = calend.reset_index()
calend.columns = ["date", "nb_acc"]

calend.head(20)
# Out:
#          date  nb_acc
# 0  2019-01-01     105
# 1  2019-01-02     106
# 2  2019-01-03     109
# 3  2019-01-04     133
# 4  2019-01-05     103
# 5  2019-01-06      81
# 6  2019-01-07     136
# 7  2019-01-08     152
# 8  2019-01-09     154
# 9  2019-01-10     142
# 10 2019-01-11     187
# 11 2019-01-12     126
# 12 2019-01-13     121
# 13 2019-01-14     142
# 14 2019-01-15     161
# 15 2019-01-16     154
# 16 2019-01-17     168
# 17 2019-01-18     220
# 18 2019-01-19     138
# 19 2019-01-20      90

# %%
nom_jour = []
num_jour = []
nom_mois = []
num_mois = []
num_sem = []
for i in range(len(calend)):
    nom_jour.append(calend["date"][i].strftime("%A")) # Nom du jour
    num_jour.append(calend["date"][i].weekday()) # Numéro du jour
    nom_mois.append(calend["date"][i].strftime("%B")) # Nom du mois
    num_mois.append(calend["date"][i].month) # Numéro du mois
    num_sem.append(calend["date"][i].strftime("%V")) # Numéro de la semaine
    
calend["nom_jour"] = nom_jour
calend["num_jour"] = num_jour
calend["nom_mois"] = nom_mois
calend["num_mois"] = num_mois
calend["num_sem"] = num_sem

calend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      365 non-null    datetime64[ns]
#  1   nb_acc    365 non-null    int64
#  2   nom_jour  365 non-null    object
#  3   num_jour  365 non-null    int64
#  4   nom_mois  365 non-null    object
#  5   num_mois  365 non-null    int64
#  6   num_sem   365 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 20.1+ KB

# %% [markdown]
# ### Tracé du calendrier
#
# Cette étape n'a pas été réalisée en python mais uniquement en R.

# %% [markdown]
# # Quelques statistiques univariées
#
# ## Nombre d'accidents par jour de la semaine

# %%
tot_jour = calend.groupby("nom_jour")["nb_acc"].sum()

tot_jour = tot_jour.reset_index()
tot_jour.columns = ["nom_jour", "nb_acc"]

# %%
fig = plt.figure(1, figsize=(15,8))

ax = sns.barplot(x='nom_jour', y='nb_acc', data=tot_jour, ci=None, color= "darkslateblue")
ax.set_title("Nombre d'accidents total par jour")
ax.set_xlabel('Jour')
ax.set_ylabel('Effectif')

rects = ax.patches

# Make some labels.
labels = tot_jour["nb_acc"]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 5, label,
            ha='center', va='bottom')

plt.show()

# %%
tot_jour = tot_jour.sort_values(by="nb_acc")

# %%
fig = plt.figure(2, figsize=(15,8))

ax = sns.barplot(x='nom_jour', y='nb_acc', data=tot_jour, ci=None, color="darkslateblue")
ax.set_title("Nombre d'accidents total par jour")
ax.set_xlabel('Jour')
ax.set_ylabel('Effectif')

rects = ax.patches

# Make some labels.
labels = tot_jour["nb_acc"]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 5, label,
            ha='center', va='bottom')

plt.show()

# %% [markdown]
# ## Nombre d'accidents par mois

# %%
tot_mois = calend.groupby("nom_mois")["nb_acc"].sum()

tot_mois = tot_mois.reset_index()
tot_mois.columns = ["nom_mois", "nb_acc"]

# %%
fig = plt.figure(3, figsize=(15, 8))


ax = sns.barplot(x='nom_mois', y='nb_acc', data=tot_mois, ci=None, color = "darkslateblue")

ax.set_title("Nombre d'accidents total par mois")
ax.set_xlabel('Mois')
ax.set_ylabel('Effectif')

rects = ax.patches

# Make some labels.
labels = tot_mois["nb_acc"]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 5, label,
            ha='center', va='bottom')


plt.show()

# %%
tot_mois = tot_mois.sort_values(by="nb_acc")

# %%
fig = plt.figure(4, figsize=(15, 8))


ax = sns.barplot(x='nom_mois', y='nb_acc', data=tot_mois, ci=None, color = "darkslateblue")

ax.set_title("Nombre d'accidents total par mois")
ax.set_xlabel('Mois')
ax.set_ylabel('Effectif')

rects = ax.patches

# Make some labels.
labels = tot_mois["nb_acc"]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + 5, label,
            ha='center', va='bottom')


plt.show()

# %% [markdown]
# # Quelques statistiques bivariées - Croisement de la gravité avec d'autres variables
# ## Gravité X Place de l'usager

# %%
tab_grav = victime.groupby("grav").size()
tab_grav
# Out:
# grav
# Blessé hospitalisé    20512
# Blessé léger          52628
# Indemne               55107
# Tué                    3480
# dtype: int64

# %%
tab_place = victime.groupby("place").size()
tab_place
# Out:
# place
# Conducteur        95735
# Passager           9099
# Passager Avant    15638
# Piéton            11255
# dtype: int64

# %%
fig = plt.figure(5, figsize=(15, 8))

ct = pd.crosstab(victime['place'],victime['grav']) 

# now stack and reset
stacked = ct.stack().reset_index().rename(columns={0:'value'})

# plot grouped bar chart
ax = sns.barplot(x=stacked.place, y=stacked.value, hue=stacked.grav, palette="PuBu")
ax.set_title("Effectif des usagers, regroupement par place")
ax.set_xlabel("Place de l'usager")
ax.set_ylabel('Effectif')

plt.legend(title = "Gravité")
plt.show()

# %%
fig = plt.figure(6, figsize=(15, 8))

# plot grouped bar chart
ax = sns.barplot(x=stacked.grav, y=stacked.value, hue=stacked.place, palette="PuBu")
ax.set_title("Effectif des usagers, regroupement par gravité")
ax.set_xlabel("Gravité")
ax.set_ylabel('Effectif')

plt.legend(title = "Place de l'usager")
plt.show()

# %% [markdown]
# ### Profils lignes

# %%
ct['Total'] = ct.sum(axis=1)

profil_ligne_grav_place = ct.copy()

for i in place :
    tot = profil_ligne_grav_place.loc[i]['Total']
    profil_ligne_grav_place.loc[i] = profil_ligne_grav_place.loc[i].div(tot)*100

    
profil_ligne_grav_place = profil_ligne_grav_place.round(0)
profil_ligne_grav_place
# Out:
# grav            Blessé hospitalisé  Blessé léger  Indemne  Tué  Total
# place
# Conducteur                    14.0          35.0     48.0  3.0    100
# Passager                      13.0          46.0     39.0  2.0    100
# Passager Avant                15.0          49.0     34.0  2.0    100
# Piéton                        29.0          64.0      3.0  5.0    100

# %%
# now stack and reset
stacked = profil_ligne_grav_place.drop(columns='Total').stack().reset_index().rename(columns={0:'value'})

fig = plt.figure(7, figsize=(15, 8))


# plot grouped bar chart
ax = sns.barplot(x=stacked.place, y=stacked.value, hue=stacked.grav, palette="PuBu")
ax.set_title("Graphique à bâtons sur les profils lignes, regroupement par place")
ax.set_xlabel("Place de l'usager")
ax.set_ylabel('Pourcentage')

plt.legend(title = "Gravité")

for p in ax.patches: 
    ax.annotate(format(p.get_height()) + "%", 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha='center', va='center', 
                   xytext=(0, 9), 
                   textcoords='offset points')
    
plt.show()

# %% [markdown]
# ### Profils colonnes

# %%
ct = ct.drop(columns = 'Total').T
ct['Total'] = ct.sum(axis=1)

profil_colonne_grav_place = ct.copy()

for i in grav :
    tot = profil_colonne_grav_place.loc[i]['Total']
    profil_colonne_grav_place.loc[i] = profil_colonne_grav_place.loc[i].div(tot)*100



profil_colonne_grav_place = profil_colonne_grav_place.round(0)
profil_colonne_grav_place
# Out:
# place               Conducteur  Passager  Passager Avant  Piéton  Total
# grav
# Blessé hospitalisé        67.0       6.0            12.0    16.0    100
# Blessé léger              64.0       8.0            15.0    14.0    100
# Indemne                   83.0       7.0            10.0     1.0    100
# Tué                       70.0       5.0            10.0    15.0    100

# %%
# now stack and reset
stacked = profil_colonne_grav_place.drop(columns='Total').stack().reset_index().rename(columns={0:'value'})

fig = plt.figure(7, figsize=(15, 8))


# plot grouped bar chart
ax = sns.barplot(x=stacked.grav, y=stacked.value, hue=stacked.place, palette="PuBu")
ax.set_title("Graphique à bâtons sur les profils colonnes, regroupement par gravité")
ax.set_xlabel("Gravité")
ax.set_ylabel('Pourcentage')

plt.legend(title = "Place de l'usager")

for p in ax.patches: 
    ax.annotate(format(p.get_height()) + "%", 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha='center', va='center', 
                   xytext=(0, 9), 
                   textcoords='offset points')
    
plt.show()

# %% [markdown]
# ## Gravité X Trajet

# %%
tab_trajet = victime.groupby("trajet").size()
tab_trajet
# Out:
# trajet
# Autre                          44018
# Courses – achats                3542
# Domicile – travail             17640
# Domicile – école                2665
# Promenade – loisirs            51365
# Utilisation professionnelle    12497
# dtype: int64

# %%
fig = plt.figure(7, figsize=(15, 8))

ct = pd.crosstab(victime['trajet'],victime['grav']) 

# now stack and reset
stacked = ct.stack().reset_index().rename(columns={0:'value'})

# plot grouped bar chart
ax = sns.barplot(x=stacked.trajet, y=stacked.value, hue=stacked.grav, palette="PuBu")
ax.set_title("Effectif des usagers, regroupement par trajet")
ax.set_xlabel("Trajet effectué")
ax.set_ylabel('Effectif')

plt.legend(title = "Gravité")

plt.show()

# %%
fig = plt.figure(8, figsize=(15, 8))

# plot grouped bar chart
ax = sns.barplot(x=stacked.grav, y=stacked.value, hue=stacked.trajet, palette="PuBu")
ax.set_title("Effectif des usagers, regroupement par gravité")
ax.set_xlabel("Gravité")
ax.set_ylabel('Effectif')

plt.legend(title = "Trajet effectué")
plt.show()

# %% [markdown]
# ### Profils Lignes

# %%
ct['Total'] = ct.sum(axis=1)

profil_ligne_grav_trajet = ct.copy()

for i in trajet :
    tot = profil_ligne_grav_trajet.loc[i]['Total']
    profil_ligne_grav_trajet.loc[i] = profil_ligne_grav_trajet.loc[i].div(tot)*100


profil_ligne_grav_trajet = profil_ligne_grav_trajet.round(0)
profil_ligne_grav_trajet
# Out:
# grav                         Blessé hospitalisé  Blessé léger  Indemne  Tué  \
# trajet
# Autre                                      13.0          45.0     41.0  2.0
# Courses – achats                           20.0          33.0     42.0  5.0
# Domicile – travail                         14.0          44.0     41.0  2.0
# Domicile – école                           15.0          52.0     31.0  1.0
# Promenade – loisirs                        21.0          38.0     38.0  4.0
# Utilisation professionnelle                 6.0          27.0     65.0  1.0
#
# grav                         Total
# trajet
# Autre                          100
# Courses – achats               100
# Domicile – travail             100
# Domicile – école               100
# Promenade – loisirs            100
# Utilisation professionnelle    100

# %%
# now stack and reset
stacked = profil_ligne_grav_trajet.drop(columns='Total').stack().reset_index().rename(columns={0:'value'})

fig = plt.figure(7, figsize=(15, 8))


# plot grouped bar chart
ax = sns.barplot(x=stacked.trajet, y=stacked.value, hue=stacked.grav, palette="PuBu")
ax.set_title("Graphique à bâtons sur les profils lignes, regroupement par trajet")
ax.set_xlabel("Trajet effectué")
ax.set_ylabel('Pourcentage')

plt.legend(title = "Gravité")

for p in ax.patches: 
    ax.annotate(format(p.get_height()) + "%", 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha='center', va='center', 
                   xytext=(0, 9), 
                   textcoords='offset points')
    
plt.show()

# %% [markdown]
# ### Profils colonnes

# %%
ct = ct.drop(columns = 'Total').T
ct['Total'] = ct.sum(axis=1)

profil_colonne_grav_trajet = ct.copy()

for i in grav :
    tot = profil_colonne_grav_trajet.loc[i]['Total']
    profil_colonne_grav_trajet.loc[i] = profil_colonne_grav_trajet.loc[i].div(tot)*100



profil_colonne_grav_trajet = profil_colonne_grav_trajet.round(0)
profil_colonne_grav_trajet
# Out:
# trajet              Autre  Courses – achats  Domicile – travail  \
# grav
# Blessé hospitalisé   27.0               4.0                12.0
# Blessé léger         37.0               2.0                15.0
# Indemne              32.0               3.0                13.0
# Tué                  28.0               5.0                 9.0
#
# trajet              Domicile – école  Promenade – loisirs  \
# grav
# Blessé hospitalisé               2.0                 52.0
# Blessé léger                     3.0                 37.0
# Indemne                          1.0                 36.0
# Tué                              1.0                 55.0
#
# trajet              Utilisation professionnelle  Total
# grav
# Blessé hospitalisé                          4.0    100
# Blessé léger                                7.0    100
# Indemne                                    15.0    100
# Tué                                         3.0    100

# %%
# now stack and reset
stacked = profil_colonne_grav_trajet.drop(columns='Total').stack().reset_index().rename(columns={0:'value'})

fig = plt.figure(7, figsize=(15, 8))


# plot grouped bar chart
ax = sns.barplot(x=stacked.grav, y=stacked.value, hue=stacked.trajet, palette="PuBu")
ax.set_title("Graphique à bâtons sur les profils colonnes, regroupement par gravité")
ax.set_xlabel("Gravité")
ax.set_ylabel('Pourcentage')

plt.legend(title = "Trajet")

for p in ax.patches: 
    ax.annotate(format(p.get_height()) + "%", 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha='center', va='center', 
                   xytext=(0, 9), 
                   textcoords='offset points')
    
plt.show()

# %% [markdown]
# ## Gravité X Conditions atmosphériques

# %%
tab_atm = victime.groupby("atm").size()
tab_atm
# Out:
# atm
# Autre                     652
# Brouillard - Fumée        719
# Neige - Grêle             616
# Normale                104276
# Pluie forte              3224
# Pluie légère            14656
# Temps couvert            4907
# Temps éblouissant        2313
# Vent fort - Tempête       364
# dtype: int64

# %%
fig = plt.figure(9, figsize=(15, 8))

ct = pd.crosstab(victime['atm'],victime['grav']) 

# now stack and reset
stacked = ct.stack().reset_index().rename(columns={0:'value'})

# plot grouped bar chart
ax = sns.barplot(x=stacked.atm, y=stacked.value, hue=stacked.grav, palette="PuBu")
ax.set_title("Effectif des usagers, regroupement par condition atmosphérique")
ax.set_xlabel("Conditions atmosphériques")
ax.set_ylabel('Effectif')

plt.legend(title = "Gravité")

plt.show()

# %%
fig = plt.figure(10, figsize=(15, 8))

# plot grouped bar chart
ax = sns.barplot(x=stacked.grav, y=stacked.value, hue=stacked.atm, palette="PuBu")
ax.set_title("Effectif des usagers, regroupement par gravité")
ax.set_xlabel("Gravité")
ax.set_ylabel('Effectif')

plt.legend(title = "Conditions atmosphériques")
plt.show()

# %% [markdown]
# ### Profils lignes

# %%
ct['Total'] = ct.sum(axis=1)

profil_ligne_grav_atm = ct.copy()

for i in atm:
    tot = profil_ligne_grav_atm.loc[i]['Total']
    profil_ligne_grav_atm.loc[i] = profil_ligne_grav_atm.loc[i].div(tot)*100


profil_ligne_grav_atm = profil_ligne_grav_atm.round(0)
profil_ligne_grav_atm
# Out:
# grav                 Blessé hospitalisé  Blessé léger  Indemne  Tué  Total
# atm
# Autre                              19.0          40.0     34.0  6.0    100
# Brouillard - Fumée                 24.0          38.0     33.0  5.0    100
# Neige - Grêle                      15.0          36.0     46.0  4.0    100
# Normale                            16.0          40.0     42.0  3.0    100
# Pluie forte                        17.0          41.0     40.0  3.0    100
# Pluie légère                       13.0          44.0     41.0  2.0    100
# Temps couvert                      14.0          42.0     41.0  3.0    100
# Temps éblouissant                  23.0          29.0     45.0  4.0    100
# Vent fort - Tempête                26.0          34.0     33.0  7.0    100

# %%
# now stack and reset
stacked = profil_ligne_grav_atm.drop(columns='Total').stack().reset_index().rename(columns={0:'value'})

fig = plt.figure(7, figsize=(15, 8))


# plot grouped bar chart
ax = sns.barplot(x=stacked.atm, y=stacked.value, hue=stacked.grav, palette="PuBu")
ax.set_title("Graphique à bâtons sur les profils lignes, regroupement par condition atmosphérique")
ax.set_xlabel("Conditions atmosphériques")
ax.set_ylabel('Pourcentage')

plt.legend(title = "Gravité")

for p in ax.patches: 
    ax.annotate(format(p.get_height()) + "%", 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha='center', va='center', 
                   xytext=(0, 9), 
                   textcoords='offset points')
    
plt.show()

# %% [markdown]
# ### Profils colonnes

# %%
ct = ct.drop(columns = 'Total').T
ct['Total'] = ct.sum(axis=1)

profil_colonne_grav_atm = ct.copy()

for i in grav :
    tot = profil_colonne_grav_atm.loc[i]['Total']
    profil_colonne_grav_atm.loc[i] = profil_colonne_grav_atm.loc[i].div(tot)*100



profil_colonne_grav_atm = profil_colonne_grav_atm.round(0)
profil_colonne_grav_atm
# Out:
# atm                 Autre  Brouillard - Fumée  Neige - Grêle  Normale  \
# grav
# Blessé hospitalisé    1.0                 1.0            0.0     79.0
# Blessé léger          1.0                 1.0            0.0     79.0
# Indemne               0.0                 0.0            1.0     80.0
# Tué                   1.0                 1.0            1.0     77.0
#
# atm                 Pluie forte  Pluie légère  Temps couvert  \
# grav
# Blessé hospitalisé          3.0          10.0            3.0
# Blessé léger                2.0          12.0            4.0
# Indemne                     2.0          11.0            4.0
# Tué                         2.0          10.0            5.0
#
# atm                 Temps éblouissant  Vent fort - Tempête  Total
# grav
# Blessé hospitalisé                3.0                  0.0    100
# Blessé léger                      1.0                  0.0    100
# Indemne                           2.0                  0.0    100
# Tué                               2.0                  1.0    100

# %%
# now stack and reset
stacked = profil_colonne_grav_atm.drop(columns='Total').stack().reset_index().rename(columns={0:'value'})

fig = plt.figure(7, figsize=(15, 8))


# plot grouped bar chart
ax = sns.barplot(x=stacked.grav, y=stacked.value, hue=stacked.atm, palette="PuBu")
ax.set_title("Graphique à bâtons sur les profils colonnes, regroupement par gravité")
ax.set_xlabel("Gravité")
ax.set_ylabel('Pourcentage')

plt.legend(title = "Condition atmosphérique")

for p in ax.patches: 
    ax.annotate(format(p.get_height()) + "%", 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha='center', va='center', 
                   xytext=(0, 9), 
                   textcoords='offset points')
    
plt.show()

# %% [markdown]
# ## Gravité X Luminosité

# %%
tab_lum = victime.groupby("lum").size()
tab_lum
# Out:
# lum
# Crépuscule ou aube                        8211
# Nuit avec éclairage public allumé        21053
# Nuit avec éclairage public non allumé     1199
# Nuit sans éclairage public               13629
# Plein jour                               87635
# dtype: int64

# %%
fig = plt.figure(11, figsize=(15, 8))

ct = pd.crosstab(victime['lum'],victime['grav']) 

# now stack and reset
stacked = ct.stack().reset_index().rename(columns={0:'value'})

# plot grouped bar chart
ax = sns.barplot(x=stacked.lum, y=stacked.value, hue=stacked.grav, palette="PuBu")
ax.set_title("Effectif des usagers, regroupement par luminosité")
ax.set_xlabel("Luminosité")
ax.set_ylabel('Effectif')

plt.legend(title = "Gravité")

plt.show()

# %%
fig = plt.figure(12, figsize=(15, 8))

# plot grouped bar chart
ax = sns.barplot(x=stacked.grav, y=stacked.value, hue=stacked.lum, palette="PuBu")
ax.set_title("Effectif des usagers, regroupement par gravité")
ax.set_xlabel("Gravité")
ax.set_ylabel('Effectif')

plt.legend(title = "Luminosité")
plt.show()

# %% [markdown]
# ### Profils lignes

# %%
ct['Total'] = ct.sum(axis=1)

profil_ligne_grav_lum = ct.copy()

for i in lum:
    tot = profil_ligne_grav_lum.loc[i]['Total']
    profil_ligne_grav_lum.loc[i] = profil_ligne_grav_lum.loc[i].div(tot)*100


profil_ligne_grav_lum = profil_ligne_grav_lum.round(0)
profil_ligne_grav_lum
# Out:
# grav                                   Blessé hospitalisé  Blessé léger  \
# lum
# Crépuscule ou aube                                   18.0          39.0
# Nuit avec éclairage public allumé                    13.0          45.0
# Nuit avec éclairage public non allumé                14.0          43.0
# Nuit sans éclairage public                           23.0          37.0
# Plein jour                                           15.0          39.0
#
# grav                                   Indemne  Tué  Total
# lum
# Crépuscule ou aube                        40.0  3.0    100
# Nuit avec éclairage public allumé         41.0  2.0    100
# Nuit avec éclairage public non allumé     39.0  4.0    100
# Nuit sans éclairage public                34.0  6.0    100
# Plein jour                                44.0  2.0    100

# %%
# now stack and reset
stacked = profil_ligne_grav_lum.drop(columns='Total').stack().reset_index().rename(columns={0:'value'})

fig = plt.figure(7, figsize=(15, 8))


# plot grouped bar chart
ax = sns.barplot(x=stacked.lum, y=stacked.value, hue=stacked.grav, palette="PuBu")
ax.set_title("Graphique à bâtons sur les profils lignes, regroupement par niveau de luminosité")
ax.set_xlabel("Luminosité")
ax.set_ylabel('Pourcentage')

plt.legend(title = "Gravité")

for p in ax.patches: 
    ax.annotate(format(p.get_height()) + "%", 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha='center', va='center', 
                   xytext=(0, 9), 
                   textcoords='offset points')
    
plt.show()

# %% [markdown]
# ### Profils colonnes

# %%
ct = ct.drop(columns = 'Total').T
ct['Total'] = ct.sum(axis=1)

profil_colonne_grav_lum = ct.copy()

for i in grav :
    tot = profil_colonne_grav_lum.loc[i]['Total']
    profil_colonne_grav_lum.loc[i] = profil_colonne_grav_lum.loc[i].div(tot)*100



profil_colonne_grav_lum = profil_colonne_grav_lum.round(0)
profil_colonne_grav_lum
# Out:
# lum                 Crépuscule ou aube  Nuit avec éclairage public allumé  \
# grav
# Blessé hospitalisé                 7.0                               13.0
# Blessé léger                       6.0                               18.0
# Indemne                            6.0                               16.0
# Tué                                7.0                               11.0
#
# lum                 Nuit avec éclairage public non allumé  \
# grav
# Blessé hospitalisé                                    1.0
# Blessé léger                                          1.0
# Indemne                                               1.0
# Tué                                                   1.0
#
# lum                 Nuit sans éclairage public  Plein jour  Total
# grav
# Blessé hospitalisé                        15.0        64.0    100
# Blessé léger                              10.0        65.0    100
# Indemne                                    8.0        69.0    100
# Tué                                       25.0        56.0    100

# %%
# now stack and reset
stacked = profil_colonne_grav_lum.drop(columns='Total').stack().reset_index().rename(columns={0:'value'})

fig = plt.figure(7, figsize=(15, 8))


# plot grouped bar chart
ax = sns.barplot(x=stacked.grav, y=stacked.value, hue=stacked.lum, palette="PuBu")
ax.set_title("Graphique à bâtons sur les profils colonnes, regroupement par gravité")
ax.set_xlabel("Gravité")
ax.set_ylabel('Pourcentage')

plt.legend(title = "Luminosité")

for p in ax.patches: 
    ax.annotate(format(p.get_height()) + "%", 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha='center', va='center', 
                   xytext=(0, 9), 
                   textcoords='offset points')
    
plt.show()

# %% [markdown]
# # ACM

# %%
print(victime)
# Out:
#              Num_Acc  id_vehicule catu           place                grav  \
# 0       201900000001  138 306 524    2  Passager Avant        Blessé léger
# 1       201900000001  138 306 524    1      Conducteur        Blessé léger
# 2       201900000001  138 306 525    1      Conducteur             Indemne
# 3       201900000002  138 306 523    1      Conducteur        Blessé léger
# 4       201900000003  138 306 520    1      Conducteur             Indemne
# ...              ...          ...  ...             ...                 ...
# 132970  201900058837  137 982 135    1      Conducteur        Blessé léger
# 132971  201900058838  137 982 132    1      Conducteur        Blessé léger
# 132972  201900058839  137 982 131    1      Conducteur  Blessé hospitalisé
# 132973  201900058840  137 982 129    1      Conducteur        Blessé léger
# 132974  201900058840  137 982 130    1      Conducteur             Indemne
#
#             sexe               trajet   hrmn  \
# 0        Féminin                Autre  01:30
# 1        Féminin  Promenade – loisirs  01:30
# 2       Masculin                Autre  01:30
# 3        Féminin                Autre  02:50
# 4       Masculin                Autre  15:15
# ...          ...                  ...    ...
# 132970   Féminin   Domicile – travail  07:50
# 132971  Masculin                Autre  02:41
# 132972  Masculin                Autre  15:20
# 132973  Masculin                Autre  20:50
# 132974  Masculin                Autre  20:50
#
#                                           lum dep    com                 agg  \
# 0       Nuit avec éclairage public non allumé  93  93053  Hors agglomération
# 1       Nuit avec éclairage public non allumé  93  93053  Hors agglomération
# 2       Nuit avec éclairage public non allumé  93  93053  Hors agglomération
# 3                  Nuit sans éclairage public  93  93066  Hors agglomération
# 4                                  Plein jour  92  92036  Hors agglomération
# ...                                       ...  ..    ...                 ...
# 132970                             Plein jour  67  67482  Hors agglomération
# 132971  Nuit avec éclairage public non allumé  94  94021  Hors agglomération
# 132972                             Plein jour  78  78640  Hors agglomération
# 132973             Nuit sans éclairage public  92  92047  Hors agglomération
# 132974             Nuit sans éclairage public  92  92047  Hors agglomération
#
#                       int            atm                                  col  \
# 0       Hors intersection        Normale       Deux véhicules - par l'arrière
# 1       Hors intersection        Normale       Deux véhicules - par l'arrière
# 2       Hors intersection        Normale       Deux véhicules - par l'arrière
# 3       Hors intersection        Normale                      Autre collision
# 4       Hors intersection        Normale  Trois véhicules et plus - en chaîne
# ...                   ...            ...                                  ...
# 132970  Hors intersection  Temps couvert  Trois véhicules et plus - en chaîne
# 132971  Hors intersection        Normale                      Autre collision
# 132972  Hors intersection        Normale                       Sans collision
# 132973  Hors intersection        Normale       Deux véhicules - par l'arrière
# 132974  Hors intersection        Normale       Deux véhicules - par l'arrière
#
#              date  nb_veh  nb_ind  age
# 0      2019-11-30       2       3   17
# 1      2019-11-30       2       3   26
# 2      2019-11-30       2       3   60
# 3      2019-11-30       1       1   25
# 4      2019-11-28       3       4   23
# ...           ...     ...     ...  ...
# 132970 2019-11-27       3       3   31
# 132971 2019-11-30       1       1   21
# 132972 2019-11-30       1       1   40
# 132973 2019-11-29       2       2   45
# 132974 2019-11-29       2       2   48
#
# [131727 rows x 19 columns]

# %%
import pandas as pd
from fanalysis.mca import MCA
import matplotlib

# %%
df = victime.iloc[:,3:15].drop(columns=["dep","com","hrmn","grav"])
df=df[["lum","agg","int","atm","col","place","sexe","trajet"]]

# %%
print(df)
# Out:
#                                           lum                 agg  \
# 0       Nuit avec éclairage public non allumé  Hors agglomération
# 1       Nuit avec éclairage public non allumé  Hors agglomération
# 2       Nuit avec éclairage public non allumé  Hors agglomération
# 3                  Nuit sans éclairage public  Hors agglomération
# 4                                  Plein jour  Hors agglomération
# ...                                       ...                 ...
# 132970                             Plein jour  Hors agglomération
# 132971  Nuit avec éclairage public non allumé  Hors agglomération
# 132972                             Plein jour  Hors agglomération
# 132973             Nuit sans éclairage public  Hors agglomération
# 132974             Nuit sans éclairage public  Hors agglomération
#
#                       int            atm                                  col  \
# 0       Hors intersection        Normale       Deux véhicules - par l'arrière
# 1       Hors intersection        Normale       Deux véhicules - par l'arrière
# 2       Hors intersection        Normale       Deux véhicules - par l'arrière
# 3       Hors intersection        Normale                      Autre collision
# 4       Hors intersection        Normale  Trois véhicules et plus - en chaîne
# ...                   ...            ...                                  ...
# 132970  Hors intersection  Temps couvert  Trois véhicules et plus - en chaîne
# 132971  Hors intersection        Normale                      Autre collision
# 132972  Hors intersection        Normale                       Sans collision
# 132973  Hors intersection        Normale       Deux véhicules - par l'arrière
# 132974  Hors intersection        Normale       Deux véhicules - par l'arrière
#
#                  place      sexe               trajet
# 0       Passager Avant   Féminin                Autre
# 1           Conducteur   Féminin  Promenade – loisirs
# 2           Conducteur  Masculin                Autre
# 3           Conducteur   Féminin                Autre
# 4           Conducteur  Masculin                Autre
# ...                ...       ...                  ...
# 132970      Conducteur   Féminin   Domicile – travail
# 132971      Conducteur  Masculin                Autre
# 132972      Conducteur  Masculin                Autre
# 132973      Conducteur  Masculin                Autre
# 132974      Conducteur  Masculin                Autre
#
# [131727 rows x 8 columns]

# %%
X=df.values

# %%
resacm=MCA(row_labels=df.index.values, var_labels=df.columns.values)

# %%
resacm.fit(X)
# Out:
# MCA(row_labels=array([     0,      1,      2, ..., 132972, 132973, 132974], dtype=int64),
#     var_labels=array(['lum', 'agg', 'int', 'atm', 'col', 'place', 'sexe', 'trajet'],
#       dtype=object))

# %%
print(resacm.eig_)
# Out:
# [[2.42218813e-01 2.05697971e-01 1.62325473e-01 1.53515091e-01
#   1.43489244e-01 1.38214609e-01 1.35039268e-01 1.30613892e-01
#   1.28999276e-01 1.28870543e-01 1.27995061e-01 1.26879819e-01
#   1.26584553e-01 1.25979769e-01 1.25547555e-01 1.25131069e-01
#   1.24867858e-01 1.23945083e-01 1.23869000e-01 1.23541733e-01
#   1.23199811e-01 1.22240695e-01 1.22022943e-01 1.20884768e-01
#   1.19367482e-01 1.18827924e-01 1.18179179e-01 1.16188845e-01
#   1.14427791e-01 1.08450172e-01 1.04205264e-01 9.48318354e-02
#   8.75704285e-02 7.71589088e-02 6.70093690e-02 6.21089063e-02]
#  [5.38264029e+00 4.57106602e+00 3.60723272e+00 3.41144647e+00
#   3.18864986e+00 3.07143575e+00 3.00087263e+00 2.90253094e+00
#   2.86665058e+00 2.86378985e+00 2.84433470e+00 2.81955154e+00
#   2.81299007e+00 2.79955042e+00 2.78994566e+00 2.78069041e+00
#   2.77484128e+00 2.75433517e+00 2.75264445e+00 2.74537185e+00
#   2.73777357e+00 2.71645988e+00 2.71162096e+00 2.68632818e+00
#   2.65261070e+00 2.64062053e+00 2.62620398e+00 2.58197433e+00
#   2.54283979e+00 2.41000382e+00 2.31567253e+00 2.10737412e+00
#   1.94600952e+00 1.71464242e+00 1.48909709e+00 1.38019792e+00]
#  [5.38264029e+00 9.95370631e+00 1.35609390e+01 1.69723855e+01
#   2.01610354e+01 2.32324711e+01 2.62333437e+01 2.91358747e+01
#   3.20025252e+01 3.48663151e+01 3.77106498e+01 4.05302013e+01
#   4.33431914e+01 4.61427418e+01 4.89326875e+01 5.17133779e+01
#   5.44882192e+01 5.72425544e+01 5.99951988e+01 6.27405707e+01
#   6.54783442e+01 6.81948041e+01 7.09064251e+01 7.35927533e+01
#   7.62453640e+01 7.88859845e+01 8.15121885e+01 8.40941628e+01
#   8.66370026e+01 8.90470064e+01 9.13626789e+01 9.34700531e+01
#   9.54160626e+01 9.71307050e+01 9.86198021e+01 1.00000000e+02]]

# %%
resacm.plot_eigenvalues(type="percentage")

# %%
varacm = resacm.col_topandas()
print(varacm)
# Out:
#                                                     col_coord_dim1  \
# lum_Crépuscule ou aube                                    0.084025
# lum_Nuit avec éclairage public allumé                    -0.793852
# lum_Nuit avec éclairage public non allumé                 0.328846
# lum_Nuit sans éclairage public                            1.543614
# lum_Plein jour                                           -0.061724
# agg_En agglomération                                     -0.608394
# agg_Hors agglomération                                    0.995535
# int_Autre intersection                                   -0.451223
# int_Giratoire                                            -0.698164
# int_Hors intersection                                     0.424476
# int_Intersection en T                                    -0.809019
# int_Intersection en X                                    -0.941952
# int_Intersection en Y                                    -0.606400
# int_Intersection à plus de 4 branches                    -1.134902
# int_Passage à niveau                                     -0.232661
# int_Place                                                -1.329883
# atm_Autre                                                 0.527796
# atm_Brouillard - Fumée                                    1.292420
# atm_Neige - Grêle                                         1.308092
# atm_Normale                                              -0.032587
# atm_Pluie forte                                           0.313552
# atm_Pluie légère                                          0.066478
# atm_Temps couvert                                        -0.077309
# atm_Temps éblouissant                                    -0.227949
# atm_Vent fort - Tempête                                   0.660287
# col_Autre collision                                      -0.362933
# col_Deux véhicules - frontale                             0.673000
# col_Deux véhicules - par l'arrière                        0.472650
# col_Deux véhicules - par le côté                         -0.664286
# col_Sans collision                                        0.836636
# col_Trois véhicules et plus - collisions multiples        0.828460
# col_Trois véhicules et plus - en chaîne                   0.817850
# place_Conducteur                                         -0.016984
# place_Passager                                            0.701594
# place_Passager Avant                                      0.439295
# place_Piéton                                             -1.033098
# sexe_Féminin                                              0.014388
# sexe_Masculin                                            -0.006835
# trajet_Autre                                             -0.246293
# trajet_Courses – achats                                  -0.499418
# trajet_Domicile – travail                                -0.070567
# trajet_Domicile – école                                  -0.657775
# trajet_Promenade – loisirs                                0.305898
# trajet_Utilisation professionnelle                       -0.008354
#
#                                                     col_coord_dim2  \
# lum_Crépuscule ou aube                                    0.028004
# lum_Nuit avec éclairage public allumé                     0.086536
# lum_Nuit avec éclairage public non allumé                 0.234234
# lum_Nuit sans éclairage public                            0.334957
# lum_Plein jour                                           -0.078710
# agg_En agglomération                                      0.048888
# agg_Hors agglomération                                   -0.079998
# int_Autre intersection                                    0.165531
# int_Giratoire                                            -0.195531
# int_Hors intersection                                     0.195514
# int_Intersection en T                                    -0.432434
# int_Intersection en X                                    -0.607607
# int_Intersection en Y                                    -0.404949
# int_Intersection à plus de 4 branches                    -0.271145
# int_Passage à niveau                                     -0.693668
# int_Place                                                 0.187605
# atm_Autre                                                 0.614583
# atm_Brouillard - Fumée                                   -0.145686
# atm_Neige - Grêle                                         0.343660
# atm_Normale                                              -0.072508
# atm_Pluie forte                                           0.589866
# atm_Pluie légère                                          0.270719
# atm_Temps couvert                                         0.129983
# atm_Temps éblouissant                                     0.249784
# atm_Vent fort - Tempête                                  -0.087331
# col_Autre collision                                       1.156348
# col_Deux véhicules - frontale                            -0.136559
# col_Deux véhicules - par l'arrière                       -0.312796
# col_Deux véhicules - par le côté                         -0.761957
# col_Sans collision                                        0.292328
# col_Trois véhicules et plus - collisions multiples       -0.297197
# col_Trois véhicules et plus - en chaîne                  -0.261458
# place_Conducteur                                         -0.363146
# place_Passager                                            0.457558
# place_Passager Avant                                      0.272597
# place_Piéton                                              2.340254
# sexe_Féminin                                              0.523063
# sexe_Masculin                                            -0.248459
# trajet_Autre                                              0.026863
# trajet_Courses – achats                                   1.032498
# trajet_Domicile – travail                                -0.514626
# trajet_Domicile – école                                   1.883615
# trajet_Promenade – loisirs                                0.201138
# trajet_Utilisation professionnelle                       -0.889243
#
#                                                     col_coord_dim3  \
# lum_Crépuscule ou aube                                   -0.406875
# lum_Nuit avec éclairage public allumé                     0.618904
# lum_Nuit avec éclairage public non allumé                 0.135779
# lum_Nuit sans éclairage public                            0.284536
# lum_Plein jour                                           -0.156669
# agg_En agglomération                                     -0.005944
# agg_Hors agglomération                                    0.009726
# int_Autre intersection                                   -0.035774
# int_Giratoire                                             0.191106
# int_Hors intersection                                    -0.220353
# int_Intersection en T                                     0.337698
# int_Intersection en X                                     0.845702
# int_Intersection en Y                                     0.114808
# int_Intersection à plus de 4 branches                     0.492110
# int_Passage à niveau                                      0.965466
# int_Place                                                -0.581882
# atm_Autre                                                -0.113456
# atm_Brouillard - Fumée                                   -0.007363
# atm_Neige - Grêle                                        -0.300451
# atm_Normale                                              -0.015189
# atm_Pluie forte                                           0.282626
# atm_Pluie légère                                          0.220591
# atm_Temps couvert                                        -0.152990
# atm_Temps éblouissant                                    -0.719850
# atm_Vent fort - Tempête                                   0.328937
# col_Autre collision                                      -0.426847
# col_Deux véhicules - frontale                             0.289615
# col_Deux véhicules - par l'arrière                       -0.377896
# col_Deux véhicules - par le côté                          0.507327
# col_Sans collision                                        0.293236
# col_Trois véhicules et plus - collisions multiples       -0.045645
# col_Trois véhicules et plus - en chaîne                  -0.519135
# place_Conducteur                                         -0.265270
# place_Passager                                            1.307957
# place_Passager Avant                                      1.368772
# place_Piéton                                             -0.702825
# sexe_Féminin                                              0.550692
# sexe_Masculin                                            -0.261583
# trajet_Autre                                              0.018011
# trajet_Courses – achats                                  -0.449881
# trajet_Domicile – travail                                -0.721620
# trajet_Domicile – école                                  -0.467593
# trajet_Promenade – loisirs                                0.533240
# trajet_Utilisation professionnelle                       -1.009335
#
#                                                     col_coord_dim4  \
# lum_Crépuscule ou aube                                    0.737762
# lum_Nuit avec éclairage public allumé                     1.134569
# lum_Nuit avec éclairage public non allumé                 0.857672
# lum_Nuit sans éclairage public                            0.967858
# lum_Plein jour                                           -0.503944
# agg_En agglomération                                      0.042878
# agg_Hors agglomération                                   -0.070163
# int_Autre intersection                                   -0.058920
# int_Giratoire                                             0.054859
# int_Hors intersection                                    -0.007516
# int_Intersection en T                                    -0.224074
# int_Intersection en X                                     0.061896
# int_Intersection en Y                                     0.316635
# int_Intersection à plus de 4 branches                     0.847865
# int_Passage à niveau                                     -0.329758
# int_Place                                                 0.914492
# atm_Autre                                                 2.211190
# atm_Brouillard - Fumée                                    2.710094
# atm_Neige - Grêle                                        -0.389956
# atm_Normale                                              -0.202090
# atm_Pluie forte                                           1.401083
# atm_Pluie légère                                          1.172976
# atm_Temps couvert                                         0.120513
# atm_Temps éblouissant                                    -2.012847
# atm_Vent fort - Tempête                                   0.767096
# col_Autre collision                                       0.234004
# col_Deux véhicules - frontale                            -0.137805
# col_Deux véhicules - par l'arrière                       -0.271732
# col_Deux véhicules - par le côté                         -0.047078
# col_Sans collision                                        0.634202
# col_Trois véhicules et plus - collisions multiples       -0.265540
# col_Trois véhicules et plus - en chaîne                  -0.304515
# place_Conducteur                                          0.079336
# place_Passager                                            0.008394
# place_Passager Avant                                     -0.470345
# place_Piéton                                             -0.028106
# sexe_Féminin                                             -0.547706
# sexe_Masculin                                             0.260164
# trajet_Autre                                              0.019021
# trajet_Courses – achats                                  -1.471877
# trajet_Domicile – travail                                 0.339116
# trajet_Domicile – école                                  -0.654539
# trajet_Promenade – loisirs                                0.007389
# trajet_Utilisation professionnelle                       -0.019290
#
#                                                     col_coord_dim5  \
# lum_Crépuscule ou aube                                   -1.728805
# lum_Nuit avec éclairage public allumé                     0.566867
# lum_Nuit avec éclairage public non allumé                 1.625523
# lum_Nuit sans éclairage public                           -0.066395
# lum_Plein jour                                            0.013885
# agg_En agglomération                                      0.064000
# agg_Hors agglomération                                   -0.104725
# int_Autre intersection                                    0.445935
# int_Giratoire                                            -0.374939
# int_Hors intersection                                     0.122104
# int_Intersection en T                                    -0.564812
# int_Intersection en X                                    -0.256074
# int_Intersection en Y                                    -0.302748
# int_Intersection à plus de 4 branches                     0.425555
# int_Passage à niveau                                      0.091908
# int_Place                                                 0.628991
# atm_Autre                                                -2.594254
# atm_Brouillard - Fumée                                   -4.017994
# atm_Neige - Grêle                                        -0.503893
# atm_Normale                                               0.140983
# atm_Pluie forte                                          -0.276520
# atm_Pluie légère                                          0.023669
# atm_Temps couvert                                        -0.803564
# atm_Temps éblouissant                                    -2.167467
# atm_Vent fort - Tempête                                  -0.849731
# col_Autre collision                                       0.037788
# col_Deux véhicules - frontale                            -0.793901
# col_Deux véhicules - par l'arrière                        0.732616
# col_Deux véhicules - par le côté                         -0.258847
# col_Sans collision                                       -0.155346
# col_Trois véhicules et plus - collisions multiples        0.140204
# col_Trois véhicules et plus - en chaîne                   0.766368
# place_Conducteur                                         -0.028348
# place_Passager                                            0.051441
# place_Passager Avant                                      0.178381
# place_Piéton                                             -0.048311
# sexe_Féminin                                             -0.127918
# sexe_Masculin                                             0.060762
# trajet_Autre                                              0.575673
# trajet_Courses – achats                                  -0.839559
# trajet_Domicile – travail                                -1.002297
# trajet_Domicile – école                                  -1.737087
# trajet_Promenade – loisirs                               -0.093849
# trajet_Utilisation professionnelle                        0.381223
#
#                                                     col_coord_dim6  \
# lum_Crépuscule ou aube                                    1.221761
# lum_Nuit avec éclairage public allumé                    -0.045279
# lum_Nuit avec éclairage public non allumé                 1.604811
# lum_Nuit sans éclairage public                           -0.315363
# lum_Plein jour                                           -0.076507
# agg_En agglomération                                      0.004939
# agg_Hors agglomération                                   -0.008081
# int_Autre intersection                                    0.586772
# int_Giratoire                                            -0.342726
# int_Hors intersection                                     0.032885
# int_Intersection en T                                    -0.105467
# int_Intersection en X                                     0.073682
# int_Intersection en Y                                    -0.750076
# int_Intersection à plus de 4 branches                     0.003232
# int_Passage à niveau                                     -2.761601
# int_Place                                                -1.365903
# atm_Autre                                                 1.965936
# atm_Brouillard - Fumée                                    1.556150
# atm_Neige - Grêle                                         0.965106
# atm_Normale                                              -0.055019
# atm_Pluie forte                                           0.125324
# atm_Pluie légère                                          0.415789
# atm_Temps couvert                                         0.145911
# atm_Temps éblouissant                                    -1.449379
# atm_Vent fort - Tempête                                  -3.075361
# col_Autre collision                                      -0.205214
# col_Deux véhicules - frontale                            -0.263599
# col_Deux véhicules - par l'arrière                        0.057143
# col_Deux véhicules - par le côté                         -0.016743
# col_Sans collision                                       -0.927611
# col_Trois véhicules et plus - collisions multiples        0.576482
# col_Trois véhicules et plus - en chaîne                   1.487923
# place_Conducteur                                         -0.000599
# place_Passager                                           -0.322936
# place_Passager Avant                                      0.322188
# place_Piéton                                             -0.181485
# sexe_Féminin                                              0.502593
# sexe_Masculin                                            -0.238736
# trajet_Autre                                              0.612912
# trajet_Courses – achats                                  -0.285092
# trajet_Domicile – travail                                 0.731452
# trajet_Domicile – école                                   0.225254
# trajet_Promenade – loisirs                               -0.544935
# trajet_Utilisation professionnelle                       -0.918773
#
#                                                     col_coord_dim7  \
# lum_Crépuscule ou aube                                   -0.253975
# lum_Nuit avec éclairage public allumé                     0.068979
# lum_Nuit avec éclairage public non allumé                 0.447286
# lum_Nuit sans éclairage public                            0.023560
# lum_Plein jour                                           -0.002559
# agg_En agglomération                                      0.042931
# agg_Hors agglomération                                   -0.070250
# int_Autre intersection                                    0.456603
# int_Giratoire                                             2.607005
# int_Hors intersection                                    -0.013185
# int_Intersection en T                                    -0.027631
# int_Intersection en X                                    -0.781776
# int_Intersection en Y                                     0.579294
# int_Intersection à plus de 4 branches                    -1.186975
# int_Passage à niveau                                     -4.917559
# int_Place                                                -0.049246
# atm_Autre                                                 0.271926
# atm_Brouillard - Fumée                                   -0.232792
# atm_Neige - Grêle                                        -3.554280
# atm_Normale                                               0.018264
# atm_Pluie forte                                           0.269160
# atm_Pluie légère                                          0.106798
# atm_Temps couvert                                        -0.731036
# atm_Temps éblouissant                                     0.469750
# atm_Vent fort - Tempête                                   0.941287
# col_Autre collision                                      -0.108793
# col_Deux véhicules - frontale                            -0.237229
# col_Deux véhicules - par l'arrière                        0.907262
# col_Deux véhicules - par le côté                         -0.068785
# col_Sans collision                                        0.829019
# col_Trois véhicules et plus - collisions multiples       -1.240558
# col_Trois véhicules et plus - en chaîne                  -0.403490
# place_Conducteur                                          0.066936
# place_Passager                                           -0.993827
# place_Passager Avant                                      0.344548
# place_Piéton                                             -0.244628
# sexe_Féminin                                              0.203039
# sexe_Masculin                                            -0.096445
# trajet_Autre                                             -0.110751
# trajet_Courses – achats                                   0.851611
# trajet_Domicile – travail                                 0.735126
# trajet_Domicile – école                                  -1.744624
# trajet_Promenade – loisirs                                0.103065
# trajet_Utilisation professionnelle                       -0.940506
#
#                                                     col_coord_dim8  \
# lum_Crépuscule ou aube                                    0.130013
# lum_Nuit avec éclairage public allumé                     0.400479
# lum_Nuit avec éclairage public non allumé                -2.148689
# lum_Nuit sans éclairage public                           -0.162238
# lum_Plein jour                                           -0.053762
# agg_En agglomération                                      0.029905
# agg_Hors agglomération                                   -0.048934
# int_Autre intersection                                    1.669254
# int_Giratoire                                            -1.638838
# int_Hors intersection                                    -0.028004
# int_Intersection en T                                     0.125839
# int_Intersection en X                                    -0.614143
# int_Intersection en Y                                     1.923659
# int_Intersection à plus de 4 branches                     1.563101
# int_Passage à niveau                                      2.108351
# int_Place                                                 1.007573
# atm_Autre                                                 3.900309
# atm_Brouillard - Fumée                                   -1.013247
# atm_Neige - Grêle                                        -0.540458
# atm_Normale                                              -0.066099
# atm_Pluie forte                                          -1.235716
# atm_Pluie légère                                          0.582331
# atm_Temps couvert                                        -0.464921
# atm_Temps éblouissant                                     1.183092
# atm_Vent fort - Tempête                                   1.113064
# col_Autre collision                                      -0.063480
# col_Deux véhicules - frontale                             1.460348
# col_Deux véhicules - par l'arrière                        0.251834
# col_Deux véhicules - par le côté                         -0.221699
# col_Sans collision                                       -1.030723
# col_Trois véhicules et plus - collisions multiples       -0.621182
# col_Trois véhicules et plus - en chaîne                   0.009778
# place_Conducteur                                         -0.019427
# place_Passager                                           -0.241252
# place_Passager Avant                                      0.411196
# place_Piéton                                             -0.211047
# sexe_Féminin                                              0.009322
# sexe_Masculin                                            -0.004428
# trajet_Autre                                              0.062718
# trajet_Courses – achats                                   0.510577
# trajet_Domicile – travail                                -0.226198
# trajet_Domicile – école                                  -0.694283
# trajet_Promenade – loisirs                               -0.043148
# trajet_Utilisation professionnelle                        0.279066
#
#                                                     col_coord_dim9  \
# lum_Crépuscule ou aube                                   -0.219157
# lum_Nuit avec éclairage public allumé                     0.042683
# lum_Nuit avec éclairage public non allumé                -0.879523
# lum_Nuit sans éclairage public                            0.320949
# lum_Plein jour                                           -0.027601
# agg_En agglomération                                     -0.043321
# agg_Hors agglomération                                    0.070887
# int_Autre intersection                                   -0.562107
# int_Giratoire                                            -0.184234
# int_Hors intersection                                    -0.000193
# int_Intersection en T                                    -0.488232
# int_Intersection en X                                     0.439070
# int_Intersection en Y                                    -0.768726
# int_Intersection à plus de 4 branches                     2.168233
# int_Passage à niveau                                     -0.719736
# int_Place                                                 2.953322
# atm_Autre                                                -5.103558
# atm_Brouillard - Fumée                                    2.153497
# atm_Neige - Grêle                                         0.443322
# atm_Normale                                              -0.172342
# atm_Pluie forte                                           0.173295
# atm_Pluie légère                                          0.836112
# atm_Temps couvert                                         0.648719
# atm_Temps éblouissant                                     1.496810
# atm_Vent fort - Tempête                                   0.052402
# col_Autre collision                                       0.096580
# col_Deux véhicules - frontale                            -0.273822
# col_Deux véhicules - par l'arrière                       -0.390590
# col_Deux véhicules - par le côté                          0.065917
# col_Sans collision                                       -0.307954
# col_Trois véhicules et plus - collisions multiples        0.327572
# col_Trois véhicules et plus - en chaîne                   0.521778
# place_Conducteur                                         -0.012691
# place_Passager                                           -1.135678
# place_Passager Avant                                      0.729160
# place_Piéton                                              0.012965
# sexe_Féminin                                              0.158894
# sexe_Masculin                                            -0.075476
# trajet_Autre                                             -0.136308
# trajet_Courses – achats                                   2.208713
# trajet_Domicile – travail                                 0.046563
# trajet_Domicile – école                                  -2.193222
# trajet_Promenade – loisirs                               -0.076127
# trajet_Utilisation professionnelle                        0.568983
#
#                                                     col_coord_dim10  ...  \
# lum_Crépuscule ou aube                                    -0.470356  ...
# lum_Nuit avec éclairage public allumé                      0.052236  ...
# lum_Nuit avec éclairage public non allumé                  1.448801  ...
# lum_Nuit sans éclairage public                             0.169279  ...
# lum_Plein jour                                            -0.014627  ...
# agg_En agglomération                                      -0.021435  ...
# agg_Hors agglomération                                     0.035075  ...
# int_Autre intersection                                     1.477112  ...
# int_Giratoire                                             -0.024967  ...
# int_Hors intersection                                     -0.060311  ...
# int_Intersection en T                                      0.449571  ...
# int_Intersection en X                                     -0.056484  ...
# int_Intersection en Y                                     -1.943451  ...
# int_Intersection à plus de 4 branches                     -2.844386  ...
# int_Passage à niveau                                       3.992733  ...
# int_Place                                                 -1.112027  ...
# atm_Autre                                                  2.634925  ...
# atm_Brouillard - Fumée                                    -0.789572  ...
# atm_Neige - Grêle                                          1.796101  ...
# atm_Normale                                                0.003544  ...
# atm_Pluie forte                                            0.966808  ...
# atm_Pluie légère                                          -0.034882  ...
# atm_Temps couvert                                         -1.685594  ...
# atm_Temps éblouissant                                      1.761064  ...
# atm_Vent fort - Tempête                                   -2.841019  ...
# col_Autre collision                                        0.048672  ...
# col_Deux véhicules - frontale                              0.107464  ...
# col_Deux véhicules - par l'arrière                        -0.779288  ...
# col_Deux véhicules - par le côté                           0.035626  ...
# col_Sans collision                                         0.358328  ...
# col_Trois véhicules et plus - collisions multiples         1.354198  ...
# col_Trois véhicules et plus - en chaîne                   -0.476094  ...
# place_Conducteur                                           0.074343  ...
# place_Passager                                            -0.139293  ...
# place_Passager Avant                                      -0.402115  ...
# place_Piéton                                               0.038954  ...
# sexe_Féminin                                              -0.184273  ...
# sexe_Masculin                                              0.087531  ...
# trajet_Autre                                               0.179743  ...
# trajet_Courses – achats                                    1.676080  ...
# trajet_Domicile – travail                                 -0.099878  ...
# trajet_Domicile – école                                   -2.161009  ...
# trajet_Promenade – loisirs                                -0.012839  ...
# trajet_Utilisation professionnelle                        -0.453566  ...
#
#                                                     col_cos2_dim27  \
# lum_Crépuscule ou aube                                    0.109764
# lum_Nuit avec éclairage public allumé                     0.003782
# lum_Nuit avec éclairage public non allumé                 0.006471
# lum_Nuit sans éclairage public                            0.032404
# lum_Plein jour                                            0.000484
# agg_En agglomération                                      0.001065
# agg_Hors agglomération                                    0.001065
# int_Autre intersection                                    0.000872
# int_Giratoire                                             0.104986
# int_Hors intersection                                     0.018651
# int_Intersection en T                                     0.027585
# int_Intersection en X                                     0.022828
# int_Intersection en Y                                     0.000002
# int_Intersection à plus de 4 branches                     0.000788
# int_Passage à niveau                                      0.000300
# int_Place                                                 0.000543
# atm_Autre                                                 0.029365
# atm_Brouillard - Fumée                                    0.018203
# atm_Neige - Grêle                                         0.021836
# atm_Normale                                               0.031471
# atm_Pluie forte                                           0.001824
# atm_Pluie légère                                          0.014433
# atm_Temps couvert                                         0.037442
# atm_Temps éblouissant                                     0.052609
# atm_Vent fort - Tempête                                   0.007069
# col_Autre collision                                       0.032180
# col_Deux véhicules - frontale                             0.009383
# col_Deux véhicules - par l'arrière                        0.010560
# col_Deux véhicules - par le côté                          0.002381
# col_Sans collision                                        0.197640
# col_Trois véhicules et plus - collisions multiples        0.000004
# col_Trois véhicules et plus - en chaîne                   0.080499
# place_Conducteur                                          0.000512
# place_Passager                                            0.009046
# place_Passager Avant                                      0.003700
# place_Piéton                                              0.000408
# sexe_Féminin                                              0.002790
# sexe_Masculin                                             0.002790
# trajet_Autre                                              0.002981
# trajet_Courses – achats                                   0.108878
# trajet_Domicile – travail                                 0.005542
# trajet_Domicile – école                                   0.020757
# trajet_Promenade – loisirs                                0.018721
# trajet_Utilisation professionnelle                        0.000625
#
#                                                     col_cos2_dim28  \
# lum_Crépuscule ou aube                                    0.013715
# lum_Nuit avec éclairage public allumé                     0.005279
# lum_Nuit avec éclairage public non allumé                 0.002053
# lum_Nuit sans éclairage public                            0.000012
# lum_Plein jour                                            0.012007
# agg_En agglomération                                      0.000317
# agg_Hors agglomération                                    0.000317
# int_Autre intersection                                    0.033724
# int_Giratoire                                             0.117703
# int_Hors intersection                                     0.002651
# int_Intersection en T                                     0.057935
# int_Intersection en X                                     0.005987
# int_Intersection en Y                                     0.000246
# int_Intersection à plus de 4 branches                     0.000141
# int_Passage à niveau                                      0.000716
# int_Place                                                 0.051538
# atm_Autre                                                 0.059054
# atm_Brouillard - Fumée                                    0.002917
# atm_Neige - Grêle                                         0.008894
# atm_Normale                                               0.038051
# atm_Pluie forte                                           0.000866
# atm_Pluie légère                                          0.000403
# atm_Temps couvert                                         0.000515
# atm_Temps éblouissant                                     0.073979
# atm_Vent fort - Tempête                                   0.000281
# col_Autre collision                                       0.000111
# col_Deux véhicules - frontale                             0.206808
# col_Deux véhicules - par l'arrière                        0.140612
# col_Deux véhicules - par le côté                          0.000704
# col_Sans collision                                        0.008674
# col_Trois véhicules et plus - collisions multiples        0.040089
# col_Trois véhicules et plus - en chaîne                   0.005316
# place_Conducteur                                          0.004007
# place_Passager                                            0.035864
# place_Passager Avant                                      0.004425
# place_Piéton                                              0.000037
# sexe_Féminin                                              0.004788
# sexe_Masculin                                             0.004788
# trajet_Autre                                              0.001623
# trajet_Courses – achats                                   0.032036
# trajet_Domicile – travail                                 0.004656
# trajet_Domicile – école                                   0.047896
# trajet_Promenade – loisirs                                0.000470
# trajet_Utilisation professionnelle                        0.013090
#
#                                                     col_cos2_dim29  \
# lum_Crépuscule ou aube                                    0.317964
# lum_Nuit avec éclairage public allumé                     0.000026
# lum_Nuit avec éclairage public non allumé                 0.004063
# lum_Nuit sans éclairage public                            0.012612
# lum_Plein jour                                            0.039861
# agg_En agglomération                                      0.000679
# agg_Hors agglomération                                    0.000679
# int_Autre intersection                                    0.040934
# int_Giratoire                                             0.019528
# int_Hors intersection                                     0.006876
# int_Intersection en T                                     0.001437
# int_Intersection en X                                     0.005521
# int_Intersection en Y                                     0.000622
# int_Intersection à plus de 4 branches                     0.002065
# int_Passage à niveau                                      0.004062
# int_Place                                                 0.002797
# atm_Autre                                                 0.033548
# atm_Brouillard - Fumée                                    0.102246
# atm_Neige - Grêle                                         0.002020
# atm_Normale                                               0.036000
# atm_Pluie forte                                           0.001577
# atm_Pluie légère                                          0.003708
# atm_Temps couvert                                         0.001771
# atm_Temps éblouissant                                     0.024101
# atm_Vent fort - Tempête                                   0.005207
# col_Autre collision                                       0.018710
# col_Deux véhicules - frontale                             0.017187
# col_Deux véhicules - par l'arrière                        0.001378
# col_Deux véhicules - par le côté                          0.000256
# col_Sans collision                                        0.057199
# col_Trois véhicules et plus - collisions multiples        0.012281
# col_Trois véhicules et plus - en chaîne                   0.016340
# place_Conducteur                                          0.005781
# place_Passager                                            0.010880
# place_Passager Avant                                      0.000346
# place_Piéton                                              0.000026
# sexe_Féminin                                              0.001560
# sexe_Masculin                                             0.001560
# trajet_Autre                                              0.098408
# trajet_Courses – achats                                   0.000659
# trajet_Domicile – travail                                 0.004375
# trajet_Domicile – école                                   0.056361
# trajet_Promenade – loisirs                                0.112176
# trajet_Utilisation professionnelle                        0.015443
#
#                                                     col_cos2_dim30  \
# lum_Crépuscule ou aube                                    0.027129
# lum_Nuit avec éclairage public allumé                     0.194311
# lum_Nuit avec éclairage public non allumé                 0.000497
# lum_Nuit sans éclairage public                            0.200111
# lum_Plein jour                                            0.000692
# agg_En agglomération                                      0.018372
# agg_Hors agglomération                                    0.018372
# int_Autre intersection                                    0.003004
# int_Giratoire                                             0.002124
# int_Hors intersection                                     0.025464
# int_Intersection en T                                     0.003527
# int_Intersection en X                                     0.006375
# int_Intersection en Y                                     0.014421
# int_Intersection à plus de 4 branches                     0.004026
# int_Passage à niveau                                      0.000004
# int_Place                                                 0.014129
# atm_Autre                                                 0.000479
# atm_Brouillard - Fumée                                    0.030471
# atm_Neige - Grêle                                         0.002187
# atm_Normale                                               0.006391
# atm_Pluie forte                                           0.000003
# atm_Pluie légère                                          0.000012
# atm_Temps couvert                                         0.009362
# atm_Temps éblouissant                                     0.001196
# atm_Vent fort - Tempête                                   0.001969
# col_Autre collision                                       0.013732
# col_Deux véhicules - frontale                             0.002686
# col_Deux véhicules - par l'arrière                        0.000371
# col_Deux véhicules - par le côté                          0.072065
# col_Sans collision                                        0.029652
# col_Trois véhicules et plus - collisions multiples        0.083033
# col_Trois véhicules et plus - en chaîne                   0.026458
# place_Conducteur                                          0.000003
# place_Passager                                            0.003805
# place_Passager Avant                                      0.000225
# place_Piéton                                              0.004993
# sexe_Féminin                                              0.007199
# sexe_Masculin                                             0.007199
# trajet_Autre                                              0.157262
# trajet_Courses – achats                                   0.000005
# trajet_Domicile – travail                                 0.036322
# trajet_Domicile – école                                   0.007744
# trajet_Promenade – loisirs                                0.024217
# trajet_Utilisation professionnelle                        0.013072
#
#                                                     col_cos2_dim31  \
# lum_Crépuscule ou aube                                    0.000211
# lum_Nuit avec éclairage public allumé                     0.065997
# lum_Nuit avec éclairage public non allumé                 0.000845
# lum_Nuit sans éclairage public                            0.024013
# lum_Plein jour                                            0.097842
# agg_En agglomération                                      0.000962
# agg_Hors agglomération                                    0.000962
# int_Autre intersection                                    0.000148
# int_Giratoire                                             0.001113
# int_Hors intersection                                     0.000909
# int_Intersection en T                                     0.000964
# int_Intersection en X                                     0.000205
# int_Intersection en Y                                     0.000013
# int_Intersection à plus de 4 branches                     0.000008
# int_Passage à niveau                                      0.000288
# int_Place                                                 0.005981
# atm_Autre                                                 0.003130
# atm_Brouillard - Fumée                                    0.002756
# atm_Neige - Grêle                                         0.000633
# atm_Normale                                               0.026632
# atm_Pluie forte                                           0.009796
# atm_Pluie légère                                          0.049775
# atm_Temps couvert                                         0.000162
# atm_Temps éblouissant                                     0.029598
# atm_Vent fort - Tempête                                   0.000020
# col_Autre collision                                       0.003884
# col_Deux véhicules - frontale                             0.019532
# col_Deux véhicules - par l'arrière                        0.011853
# col_Deux véhicules - par le côté                          0.002684
# col_Sans collision                                        0.037398
# col_Trois véhicules et plus - collisions multiples        0.001352
# col_Trois véhicules et plus - en chaîne                   0.035458
# place_Conducteur                                          0.004354
# place_Passager                                            0.012525
# place_Passager Avant                                      0.008499
# place_Piéton                                              0.012173
# sexe_Féminin                                              0.107676
# sexe_Masculin                                             0.107676
# trajet_Autre                                              0.003068
# trajet_Courses – achats                                   0.084795
# trajet_Domicile – travail                                 0.003742
# trajet_Domicile – école                                   0.156244
# trajet_Promenade – loisirs                                0.012573
# trajet_Utilisation professionnelle                        0.142149
#
#                                                     col_cos2_dim32  \
# lum_Crépuscule ou aube                                1.482523e-05
# lum_Nuit avec éclairage public allumé                 3.832740e-02
# lum_Nuit avec éclairage public non allumé             2.226107e-03
# lum_Nuit sans éclairage public                        5.342649e-02
# lum_Plein jour                                        9.776510e-02
# agg_En agglomération                                  1.034650e-04
# agg_Hors agglomération                                1.034650e-04
# int_Autre intersection                                3.658767e-07
# int_Giratoire                                         2.806422e-03
# int_Hors intersection                                 5.915679e-04
# int_Intersection en T                                 3.547701e-03
# int_Intersection en X                                 2.427933e-04
# int_Intersection en Y                                 2.916310e-05
# int_Intersection à plus de 4 branches                 1.851190e-03
# int_Passage à niveau                                  2.077815e-03
# int_Place                                             2.714923e-03
# atm_Autre                                             1.190666e-02
# atm_Brouillard - Fumée                                2.083035e-02
# atm_Neige - Grêle                                     2.628034e-03
# atm_Normale                                           8.527723e-02
# atm_Pluie forte                                       2.344694e-02
# atm_Pluie légère                                      6.192842e-02
# atm_Temps couvert                                     2.567142e-03
# atm_Temps éblouissant                                 1.527896e-02
# atm_Vent fort - Tempête                               8.660107e-04
# col_Autre collision                                   4.230174e-03
# col_Deux véhicules - frontale                         2.735770e-03
# col_Deux véhicules - par l'arrière                    7.794197e-03
# col_Deux véhicules - par le côté                      1.113507e-03
# col_Sans collision                                    7.367647e-03
# col_Trois véhicules et plus - collisions multiples    5.010284e-04
# col_Trois véhicules et plus - en chaîne               3.429695e-03
# place_Conducteur                                      1.119249e-01
# place_Passager                                        5.629360e-02
# place_Passager Avant                                  6.199638e-02
# place_Piéton                                          8.987690e-04
# sexe_Féminin                                          6.361476e-05
# sexe_Masculin                                         6.361476e-05
# trajet_Autre                                          2.160243e-03
# trajet_Courses – achats                               6.954513e-04
# trajet_Domicile – travail                             1.211561e-01
# trajet_Domicile – école                               6.701654e-06
# trajet_Promenade – loisirs                            2.218578e-01
# trajet_Utilisation professionnelle                    8.486680e-02
#
#                                                     col_cos2_dim33  \
# lum_Crépuscule ou aube                                    0.004363
# lum_Nuit avec éclairage public allumé                     0.037274
# lum_Nuit avec éclairage public non allumé                 0.003830
# lum_Nuit sans éclairage public                            0.062509
# lum_Plein jour                                            0.127862
# agg_En agglomération                                      0.000081
# agg_Hors agglomération                                    0.000081
# int_Autre intersection                                    0.000314
# int_Giratoire                                             0.000530
# int_Hors intersection                                     0.008625
# int_Intersection en T                                     0.001235
# int_Intersection en X                                     0.004898
# int_Intersection en Y                                     0.000292
# int_Intersection à plus de 4 branches                     0.000052
# int_Passage à niveau                                      0.000106
# int_Place                                                 0.000076
# atm_Autre                                                 0.001880
# atm_Brouillard - Fumée                                    0.002271
# atm_Neige - Grêle                                         0.000017
# atm_Normale                                               0.024961
# atm_Pluie forte                                           0.007845
# atm_Pluie légère                                          0.025257
# atm_Temps couvert                                         0.000001
# atm_Temps éblouissant                                     0.002995
# atm_Vent fort - Tempête                                   0.000425
# col_Autre collision                                       0.012071
# col_Deux véhicules - frontale                             0.008200
# col_Deux véhicules - par l'arrière                        0.000782
# col_Deux véhicules - par le côté                          0.002026
# col_Sans collision                                        0.004686
# col_Trois véhicules et plus - collisions multiples        0.001061
# col_Trois véhicules et plus - en chaîne                   0.000776
# place_Conducteur                                          0.163989
# place_Passager                                            0.065967
# place_Passager Avant                                      0.133540
# place_Piéton                                              0.000106
# sexe_Féminin                                              0.200038
# sexe_Masculin                                             0.200038
# trajet_Autre                                              0.000522
# trajet_Courses – achats                                   0.000567
# trajet_Domicile – travail                                 0.037978
# trajet_Domicile – école                                   0.004665
# trajet_Promenade – loisirs                                0.002937
# trajet_Utilisation professionnelle                        0.023535
#
#                                                     col_cos2_dim34  \
# lum_Crépuscule ou aube                                1.574655e-04
# lum_Nuit avec éclairage public allumé                 1.363843e-02
# lum_Nuit avec éclairage public non allumé             1.542658e-04
# lum_Nuit sans éclairage public                        9.387532e-03
# lum_Plein jour                                        1.029301e-03
# agg_En agglomération                                  1.351032e-03
# agg_Hors agglomération                                1.351032e-03
# int_Autre intersection                                1.307692e-03
# int_Giratoire                                         9.338183e-03
# int_Hors intersection                                 2.251625e-01
# int_Intersection en T                                 4.912737e-02
# int_Intersection en X                                 1.197901e-01
# int_Intersection en Y                                 3.397461e-03
# int_Intersection à plus de 4 branches                 3.354050e-03
# int_Passage à niveau                                  2.866489e-04
# int_Place                                             3.062757e-03
# atm_Autre                                             5.437532e-06
# atm_Brouillard - Fumée                                2.400408e-05
# atm_Neige - Grêle                                     1.293264e-05
# atm_Normale                                           8.758580e-07
# atm_Pluie forte                                       1.518198e-05
# atm_Pluie légère                                      1.034522e-04
# atm_Temps couvert                                     1.383836e-05
# atm_Temps éblouissant                                 6.626551e-04
# atm_Vent fort - Tempête                               3.290016e-05
# col_Autre collision                                   2.492317e-02
# col_Deux véhicules - frontale                         2.302793e-02
# col_Deux véhicules - par l'arrière                    5.240222e-02
# col_Deux véhicules - par le côté                      1.356610e-01
# col_Sans collision                                    1.290993e-02
# col_Trois véhicules et plus - collisions multiples    1.420036e-02
# col_Trois véhicules et plus - en chaîne               5.059041e-02
# place_Conducteur                                      2.958931e-02
# place_Passager                                        2.021057e-05
# place_Passager Avant                                  3.939321e-04
# place_Piéton                                          6.519168e-02
# sexe_Féminin                                          2.120222e-02
# sexe_Masculin                                         2.120222e-02
# trajet_Autre                                          6.853817e-04
# trajet_Courses – achats                               4.553555e-06
# trajet_Domicile – travail                             1.593731e-03
# trajet_Domicile – école                               2.497683e-03
# trajet_Promenade – loisirs                            1.555457e-03
# trajet_Utilisation professionnelle                    1.998863e-03
#
#                                                     col_cos2_dim35  \
# lum_Crépuscule ou aube                                4.279685e-04
# lum_Nuit avec éclairage public allumé                 5.604872e-02
# lum_Nuit avec éclairage public non allumé             1.228012e-05
# lum_Nuit sans éclairage public                        7.165242e-02
# lum_Plein jour                                        5.056307e-08
# agg_En agglomération                                  3.173390e-01
# agg_Hors agglomération                                3.173390e-01
# int_Autre intersection                                8.307724e-05
# int_Giratoire                                         1.667749e-03
# int_Hors intersection                                 1.288288e-02
# int_Intersection en T                                 3.937331e-03
# int_Intersection en X                                 2.393226e-03
# int_Intersection en Y                                 5.988002e-04
# int_Intersection à plus de 4 branches                 2.272686e-04
# int_Passage à niveau                                  7.572296e-05
# int_Place                                             1.871090e-03
# atm_Autre                                             8.447952e-06
# atm_Brouillard - Fumée                                9.651662e-05
# atm_Neige - Grêle                                     5.371054e-04
# atm_Normale                                           3.193973e-04
# atm_Pluie forte                                       6.292828e-05
# atm_Pluie légère                                      1.273878e-04
# atm_Temps couvert                                     1.686133e-04
# atm_Temps éblouissant                                 4.533321e-04
# atm_Vent fort - Tempête                               7.512797e-07
# col_Autre collision                                   1.525272e-03
# col_Deux véhicules - frontale                         6.083515e-04
# col_Deux véhicules - par l'arrière                    2.242779e-04
# col_Deux véhicules - par le côté                      1.505895e-02
# col_Sans collision                                    4.192892e-04
# col_Trois véhicules et plus - collisions multiples    4.765097e-03
# col_Trois véhicules et plus - en chaîne               3.581827e-03
# place_Conducteur                                      5.586816e-03
# place_Passager                                        3.429561e-03
# place_Passager Avant                                  4.059698e-03
# place_Piéton                                          6.051741e-02
# sexe_Féminin                                          2.582213e-04
# sexe_Masculin                                         2.582213e-04
# trajet_Autre                                          4.962417e-03
# trajet_Courses – achats                               7.916456e-06
# trajet_Domicile – travail                             2.230196e-04
# trajet_Domicile – école                               2.739800e-04
# trajet_Promenade – loisirs                            4.302008e-03
# trajet_Utilisation professionnelle                    1.457950e-04
#
#                                                     col_cos2_dim36
# lum_Crépuscule ou aube                                    0.000054
# lum_Nuit avec éclairage public allumé                     0.000160
# lum_Nuit avec éclairage public non allumé                 0.000061
# lum_Nuit sans éclairage public                            0.010616
# lum_Plein jour                                            0.003845
# agg_En agglomération                                      0.017204
# agg_Hors agglomération                                    0.017204
# int_Autre intersection                                    0.000262
# int_Giratoire                                             0.000960
# int_Hors intersection                                     0.055409
# int_Intersection en T                                     0.013013
# int_Intersection en X                                     0.030156
# int_Intersection en Y                                     0.001212
# int_Intersection à plus de 4 branches                     0.000815
# int_Passage à niveau                                      0.000210
# int_Place                                                 0.001028
# atm_Autre                                                 0.000002
# atm_Brouillard - Fumée                                    0.000015
# atm_Neige - Grêle                                         0.000005
# atm_Normale                                               0.000529
# atm_Pluie forte                                           0.000203
# atm_Pluie légère                                          0.000108
# atm_Temps couvert                                         0.000164
# atm_Temps éblouissant                                     0.000090
# atm_Vent fort - Tempête                                   0.000008
# col_Autre collision                                       0.197358
# col_Deux véhicules - frontale                             0.003129
# col_Deux véhicules - par l'arrière                        0.002071
# col_Deux véhicules - par le côté                          0.108328
# col_Sans collision                                        0.001995
# col_Trois véhicules et plus - collisions multiples        0.003077
# col_Trois véhicules et plus - en chaîne                   0.001407
# place_Conducteur                                          0.054448
# place_Passager                                            0.000008
# place_Passager Avant                                      0.000817
# place_Piéton                                              0.162001
# sexe_Féminin                                              0.001942
# sexe_Masculin                                             0.001942
# trajet_Autre                                              0.003861
# trajet_Courses – achats                                   0.000174
# trajet_Domicile – travail                                 0.000254
# trajet_Domicile – école                                   0.003532
# trajet_Promenade – loisirs                                0.002876
# trajet_Utilisation professionnelle                        0.000788
#
# [44 rows x 108 columns]

# %%
print(resacm.col_contrib_)
# Out:
# [[2.27111519e-02 2.97068498e-03 7.94634711e-01 ... 2.39198127e-02
#   7.48574023e-02 1.01913094e-02]
#  [5.19781545e+00 7.27304011e-02 4.71421621e+00 ... 1.85634747e+00
#   8.78437681e+00 2.70796205e-02]
#  [5.07961138e-02 3.03476584e-02 1.29221077e-02 ... 2.47640967e-02
#   2.26989571e-03 1.21345636e-02]
#  ...
#  [4.51730423e-01 4.36201001e+00 3.40628843e-01 ... 3.96446748e-01
#   5.00745271e-02 6.96531734e-01]
#  [1.88298783e+00 9.58655542e-01 8.53808815e+00 ... 1.53729753e-01
#   4.89577726e-01 3.53169360e-01]
#  [3.41691395e-04 4.55881739e+00 7.44259884e+00 ... 2.93101265e-01
#   2.46165859e-02 1.43457737e-01]]

# %%
print(resacm.col_cos2_)
# Out:
# [[4.69341117e-04 5.21348558e-05 1.10051452e-02 ... 1.57465502e-04
#   4.27968544e-04 5.40039389e-05]
#  [1.19880324e-01 1.42450892e-03 7.28643935e-02 ... 1.36384347e-02
#   5.60487158e-02 1.60145831e-04]
#  [9.93343521e-04 5.03983477e-04 1.69348415e-04 ... 1.54265806e-04
#   1.22801179e-05 6.08469968e-05]
#  ...
#  [8.93415759e-03 7.32627241e-02 4.51475817e-03 ... 2.49768309e-03
#   2.73979950e-04 3.53232932e-03]
#  [5.98093986e-02 2.58586975e-02 1.81744535e-01 ... 1.55545718e-03
#   4.30200816e-03 2.87641106e-03]
#  [7.31511499e-06 8.28822340e-02 1.06780151e-01 ... 1.99886293e-03
#   1.45794988e-04 7.87511856e-04]]

# %%
resacm.mapping_col(num_x_axis=1, num_y_axis=2,short_labels=True,figsize=(14, 10))

# %%
resacm.mapping(num_x_axis=1, num_y_axis=2,figsize=(14, 10))
